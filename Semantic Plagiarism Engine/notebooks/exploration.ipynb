# %% [markdown]
# # Exploration Notebook
#
# This notebook is intentionally lightweight. The graded implementation is in `src/plagiarism_engine/` and is executed through the CLI.

# %%
from plagiarism_engine.preprocessing import tokenize, preprocess
text = 'A plagiarism engine detects copied or rewritten documents.'
print(tokenize(text))
print(preprocess(text, shingle_size=3))
